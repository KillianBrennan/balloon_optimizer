# %%
# auto reload
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt

from control_altitude import *

# %%
altitudes = np.arange(0, 10000, 100)
preessures = pressure_from_altitude(altitudes)

plt.plot(preessures/100,altitudes/1000)
plt.ylabel("Altitude (km)")
plt.xlabel("Pressure (hPa)")
# Out:
# Text(0.5, 0, 'Pressure (hPa)')

# %%
# balast_events = [(3600, 10), (7200, 10), (10800, 10), (14400, 10), (18000, 10)]
balast_events = [(i, 1) for i in range(0, 100*3600, 360)]
venting_events = [(5400, .2), (9000, .1)]
# venting_events = []
times, altitudes, gas_masses = model_altitude(balast_events, venting_events)

fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)

ax1.plot(times/3600, altitudes/1000)
ax1.set_ylabel("Altitude (km)")

ax2.plot(times/3600, gas_masses)
ax2.set_xlabel("Time (hours)")
ax2.set_ylabel("Gas mass (kg)")

plt.tight_layout()
